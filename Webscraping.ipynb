# %%
# !pip install mysql.connector
# Out:
# Requirement already satisfied: mysql.connector in d:\anaconda.pytho\lib\site-packages (2.2.9)
# WARNING: Ignoring invalid distribution ~umpy (D:\anaconda.pytho\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\anaconda.pytho\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\anaconda.pytho\Lib\site-packages)

# %%
import mysql.connector

# %%
import pandas as pd

# %%
pd.read_sql_query("select * from country",conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pd.read_sql_query("select * from country",conn)
#
# NameError: name 'conn' is not defined

# %% [raw]
# pd.read_sql_query("select * from country ",conn)

# %% [markdown]
# # Web Scraping

# %%
import pandas as pd

import requests
from bs4 import BeautifulSoup

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

webpage = requests.get("https://www.ambitionbox.com/list-of-companies?page=1", headers=headers).text
print(html)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 headers = {
#       2     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
#       3 }
# ----> 5 webpage = requests.get("https://www.ambitionbox.com/list-of-companies?page=1", headers=headers).text
#       6 print(html)
#
# NameError: name 'requests' is not defined

# %%
soup=BeautifulSoup(webpage,'lxml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 soup=BeautifulSoup(webpage,'lxml')
#
# NameError: name 'BeautifulSoup' is not defined

# %%
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(soup.prettify())
#
# NameError: name 'soup' is not defined

# %%
len(soup.find_all('h2'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 len(soup.find_all('h2'))
#
# NameError: name 'soup' is not defined

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 for i in soup.find_all('h2'):
#       2     print(i.text.strip())
#
# NameError: name 'soup' is not defined

# %%
len(soup.find_all('div', class_=['rating_star_container']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 len(soup.find_all('div', class_=['rating_star_container']))
#
# NameError: name 'soup' is not defined

# %%
for i in soup.find_all('div'.strip()):
    print(i.text.strip())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 for i in soup.find_all('div'.strip()):
#       2     print(i.text.strip())
#
# NameError: name 'soup' is not defined

# %%
soup.find_all('span',class_=['companyCardWrapper__companyRatingCount'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 soup.find_all('span',class_=['companyCardWrapper__companyRatingCount'])
#
# NameError: name 'soup' is not defined

# %%
import numpy as np
import pandas as pd
