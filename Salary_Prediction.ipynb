# %% [markdown]
# <a href="https://colab.research.google.com/github/1ashish1105/Machine_Learning/blob/main/Salary_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Salary_Data.csv')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
pip install ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 27.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 85.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 49.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load dataset
df = pd.read_csv("Salary_Data.csv")

# Create profile report
profile = ProfileReport(df, title="Salary Data Report", explorative=True)

# Save report as HTML
profile.to_file("salary_report.html")

# Display in notebook
profile
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_7334/1364330272.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport
#       3
#       4 # Load dataset
#       5 df = pd.read_csv("Salary_Data.csv")
#
# ModuleNotFoundError: No module named 'ydata_profiling'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
plt.scatter(df["YearsExperience"],df["Salary"])

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
from numpy.random.mtrand import RandomState
x_train,x_test,y_train,y_test=train_test_split(df[["YearsExperience"]],df["Salary"],test_size=0.2,random_state=0)

# %%
y_train.size
# Out:
# 24

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_train)
plt.plot(x_train,y_pred,color='red')
plt.scatter(x_train,y_train)
m=lr.coef_
b=lr.intercept_
print(m)
print(b)
# Out:
# [9312.57512673]
# 26780.09915062818

# %%
print(m)
print(b)
# Out:
# [9312.57512673]
# 26780.09915062818

# %%
lr.predict(x_test)
# Out:
# array([ 40748.96184072, 122699.62295594,  64961.65717022,  63099.14214487,
#        115249.56285456, 107799.50275317])

# %%
from sklearn.metrics import r2_score
y_pred = lr.predict(x_test)

r = r2_score(y_test, y_pred)
print(r)
# Out:
# 0.988169515729126

# %%
salary=lr.predict([[6]])
print(salary)
# Out:
# [82655.549911]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# !pip install nbstripout
# !nbstripout Salary_Prediction_System.ipynb
# Out:
# ...
# Could not strip 'Salary_Prediction_System.ipynb': file not found
