# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/live"

headers = {
	"x-rapidapi-key": "93032e255dmsh7c1ed7613dfdce2p1f9913jsn9260b28934cc",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'typeMatches': [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 11377, 'seriesName': 'Cambodia tour of Indonesia, 2025', 'matches': [{'matchInfo': {'matchId': 141430, 'seriesId': 11377, 'seriesName': 'Cambodia tour of Indonesia, 2025', 'matchDesc': '6th T20I', 'matchFormat': 'T20', 'startDate': '1766728800000', 'endDate': '1766741400000', 'state': 'Complete', 'status': 'Indonesia won by 3 wkts', 'team1': {'teamId': 1447, 'teamName': 'Cambodia', 'teamSName': 'CBD', 'imageId': 254834}, 'team2': {'teamId': 566, 'teamName': 'Indonesia', 'teamSName': 'IDN', 'imageId': 172618}, 'venueInfo': {'id': 1179, 'ground': 'Udayana Cricket Ground', 'city': 'Bali', 'timezone': '+07:00', 'latitude': '8.409518', 'longitude': '115.188919'}, 'currBatTeamId': 566, 'seriesStartDt': '1766448000000', 'seriesEndDt': '1767052800000', 'isTimeAnnounced': True, 'stateTitle': 'Complete'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 102, 'wickets': 1, 'overs':
# ...

# %%
import pandas as pd

matches_list = []

for type_match in data.get("typeMatches", []):
    for series in type_match.get("seriesMatches", []):

        if "seriesAdWrapper" not in series:
            continue

        wrapper = series["seriesAdWrapper"]

        for match in wrapper.get("matches", []):
            info = match.get("matchInfo", {})
            team1 = info.get("team1", {})
            team2 = info.get("team2", {})
            venue = info.get("venueInfo", {})

            matches_list.append({
                "matchId": info.get("matchId"),
                "seriesName": wrapper.get("seriesName"),
                "matchDesc": info.get("matchDesc"),
                "matchFormat": info.get("matchFormat"),
                "status": info.get("status"),
                "startDate": info.get("startDate"),
                "team1": team1.get("teamName"),
                "team2": team2.get("teamName"),
                "venue": venue.get("ground"),
                "city": venue.get("city")
            })

# %%
print(len(matches_list))   # must be > 0
df = pd.DataFrame(matches_list)
df
# Out:
# 0
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(data.keys())
# Out:
# dict_keys(['message'])

# %%
df = pd.DataFrame(matches_list)
